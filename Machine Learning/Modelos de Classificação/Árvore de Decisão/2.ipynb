# %%
import pandas as pd

DATA_PATH = 'data/vendas.xlsx'

df = pd.read_excel(DATA_PATH)
df.head(4)
# Out:
#    media_rating  media_pedidos test cliente_comprou
# 0           1.5             11   No             Yes
# 1           2.5             11   No              No
# 2           2.5             11   No              No
# 3           1.5             13   No             Yes

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

df['test'] = le.fit_transform(df['test'])

# %%
X = df.drop(columns=['cliente_comprou'])
y = df['cliente_comprou']

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree

dtc = DecisionTreeClassifier()
dtc.fit(X, y)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(40, 20))
fig = plot_tree(dtc, class_names=['yes', 'no'], filled=True)
