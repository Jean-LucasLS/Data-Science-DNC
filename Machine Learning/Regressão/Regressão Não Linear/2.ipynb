# %%
import pandas as pd

DATA_PATH = 'house.xlsx'

df = pd.read_excel(DATA_PATH)
df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea ExterQual  ... WoodDeckSF  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 40 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int64
#  7   YearRemodAdd   1460 non-null   int64
#  8   MasVnrArea     1452 non-null   float64
#  9   ExterQual      1460 non-null   object
#  10  ExterCond      1460 non-null   object
#  11  BsmtFinSF1     1460 non-null   int64
#  12  BsmtFinSF2     1460 non-null   int64
#  13  BsmtUnfSF      1460 non-null   int64
#  14  TotalBsmtSF    1460 non-null   int64
#  15  1stFlrSF       1460 non-null   int64
#  16  2ndFlrSF       1460 non-null   int64
#  17  LowQualFinSF   1460 non-null   int64
# ...

# %%
df.dropna(inplace=True)

# %%
df = pd.get_dummies(df)
df
# Out:
#         Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  \
# 0        1          60         65.0     8450            7            5
# 1        2          20         80.0     9600            6            8
# 2        3          60         68.0    11250            7            5
# 3        4          70         60.0     9550            7            5
# 4        5          60         84.0    14260            8            5
# ...    ...         ...          ...      ...          ...          ...
# 1455  1456          60         62.0     7917            6            5
# 1456  1457          20         85.0    13175            6            6
# 1457  1458          70         66.0     9042            7            9
# 1458  1459          20         68.0     9717            5            6
# 1459  1460          20         75.0     9937            5            6
#
#       YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  YrSold  SalePrice  \
# ...

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1121.000000  1121.000000  1121.000000    1121.000000  1121.000000
# mean    726.842105    56.146298    70.665477   10122.956289     6.212310
# std     420.769012    41.772684    24.266812    8129.302641     1.380822
# min       1.000000    20.000000    21.000000    1300.000000     2.000000
# 25%     364.000000    20.000000    60.000000    7590.000000     5.000000
# 50%     725.000000    50.000000    70.000000    9416.000000     6.000000
# 75%    1091.000000    70.000000    80.000000   11361.000000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  ...  \
# count  1121.000000  1121.000000   1121.000000  1121.000000  1121.000000  ...
# mean      5.561106  1972.264942   1985.683318   108.487957   438.399643  ...
# std       1.068236    30.967730     21.025974   189.500966   468.385038  ...
# ...

# %%
X = df.drop(columns=['SalePrice'])
y = df['SalePrice']

feature_list = X.columns

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from sklearn import metrics
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor, GradientBoostingRegressor

# %%
rfr = RandomForestRegressor(n_estimators=100, random_state=42)
rfr.fit(X_train, y_train)

rfr_pred = rfr.predict(X_test)
print(f'R² -> {(rfr.score(X, y)).round(2)}\n\
Mean Absolute Error -> {(metrics.mean_absolute_error(y_test, rfr_pred)).round(2)}\n\
Mean Squared  Error -> {(metrics.mean_squared_error(y_test, rfr_pred)).round(2)}')
# Out:
# R² -> 0.95
# Mean Absolute Error -> 19730.39
# Mean Squared  Error -> 1003224505.58

# %%
ada = AdaBoostRegressor(n_estimators=100, random_state=42)
ada.fit(X_train, y_train)

ada_pred   = ada.predict(X_test)
ada_error  = abs(ada_pred - y_test)
print(f'R² -> {(ada.score(X, y)).round(2)}\n\
Mean Absolute Error -> {(metrics.mean_absolute_error(y_test, ada_pred)).round(2)}\n\
Mean Squared  Error -> {(metrics.mean_squared_error(y_test, ada_pred)).round(2)}')
# Out:
# R² -> 0.87
# Mean Absolute Error -> 24173.73
# Mean Squared  Error -> 1369611007.61

# %%
gbr = GradientBoostingRegressor(n_estimators=100, random_state=42)
gbr.fit(X_train, y_train)

gbr_pred   = gbr.predict(X_test)
gbr_error  = abs(gbr_pred - y_test)
print(f'R² -> {(gbr.score(X, y)).round(2)}\n\
Mean Absolute Error -> {(metrics.mean_absolute_error(y_test, gbr_pred)).round(2)}\n\
Mean Squared  Error -> {(metrics.mean_squared_error(y_test, gbr_pred)).round(2)}')
# Out:
# R² -> 0.95
# Mean Absolute Error -> 18406.25
# Mean Squared  Error -> 814930642.45

# %%
rfr_tree = RandomForestRegressor(max_depth=3)
rfr_tree.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=3)

# %%
importances = list(rfr_tree.feature_importances_)
feature_importance = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importance = sorted(feature_importance, key=lambda x: x[1], reverse=True)
[print(f'Feature: {feature:20} Importante: {importance}') for feature, importance in feature_importance if importance > 0]
# Out:
# Feature: OverallQual          Importante: 0.76
# Feature: GrLivArea            Importante: 0.08
# Feature: 2ndFlrSF             Importante: 0.03
# Feature: GarageCars           Importante: 0.03
# Feature: BsmtFinSF1           Importante: 0.02
# Feature: FullBath             Importante: 0.02
# Feature: LotArea              Importante: 0.01
# Feature: TotalBsmtSF          Importante: 0.01
# Feature: 1stFlrSF             Importante: 0.01
# [None, None, None, None, None, None, None, None, None]

# %%
importances = list(ada.feature_importances_)
feature_importance = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importance = sorted(feature_importance, key=lambda x: x[1], reverse=True)
[print(f'Feature: {feature:20} Importante: {importance}') for feature, importance in feature_importance if importance > 0]
# Out:
# Feature: OverallQual          Importante: 0.26
# Feature: 2ndFlrSF             Importante: 0.15
# Feature: GrLivArea            Importante: 0.12
# Feature: OpenPorchSF          Importante: 0.08
# Feature: LotArea              Importante: 0.06
# Feature: GarageCars           Importante: 0.05
# Feature: ScreenPorch          Importante: 0.04
# Feature: YearBuilt            Importante: 0.03
# Feature: BsmtFinSF1           Importante: 0.03
# Feature: FullBath             Importante: 0.03
# Feature: PoolArea             Importante: 0.03
# Feature: LotFrontage          Importante: 0.02
# Feature: 1stFlrSF             Importante: 0.02
# Feature: WoodDeckSF           Importante: 0.02
# Feature: Id                   Importante: 0.01
# Feature: YearRemodAdd         Importante: 0.01
# Feature: TotalBsmtSF          Importante: 0.01
# Feature: BedroomAbvGr         Importante: 0.01
# Feature: GarageArea           Importante: 0.01
# Feature: MoSold               Importante: 0.01
# [None,
#  None,
# ...

# %%
importances = list(gbr.feature_importances_)
feature_importance = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
feature_importance = sorted(feature_importance, key=lambda x: x[1], reverse=True)
[print(f'Feature: {feature:20} Importante: {importance}') for feature, importance in feature_importance if importance > 0]
# Out:
# Feature: OverallQual          Importante: 0.54
# Feature: GrLivArea            Importante: 0.1
# Feature: TotalBsmtSF          Importante: 0.07
# Feature: 2ndFlrSF             Importante: 0.05
# Feature: BsmtFinSF1           Importante: 0.04
# Feature: GarageCars           Importante: 0.04
# Feature: LotArea              Importante: 0.02
# Feature: YearBuilt            Importante: 0.02
# Feature: YearRemodAdd         Importante: 0.02
# Feature: 1stFlrSF             Importante: 0.02
# Feature: FullBath             Importante: 0.02
# Feature: LotFrontage          Importante: 0.01
# Feature: OverallCond          Importante: 0.01
# Feature: Fireplaces           Importante: 0.01
# Feature: GarageArea           Importante: 0.01
# Feature: OpenPorchSF          Importante: 0.01
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]
